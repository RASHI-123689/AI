# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Problem-1
#Dataoverview
df = pd.read_csv('/content/drive/MyDrive/Coursework1/RashiBhattaL5CG12.ipynb')

print("First 10 rows:")
print(df.head(10))

print("\nNumber of rows and columns:")
print(df.shape)

print("\nColumns and data types:")
df.dtypes
# Out:
# First 10 rows:
# Empty DataFrame
# ...

# %%
#Basic Statistics

mean_score = df['score'].mean()
median_score = df['score'].median()
std_dev_score = df['score'].std()

print(f"Mean Score: {mean_score}")
print(f"Median Score: {median_score}")
print(f"Standard Deviation of Score: {std_dev_score}")

highest_score_country = df.loc[df['score'].idxmax()]
lowest_score_country = df.loc[df['score'].idxmin()]

print("\nCountry with the highest happiness score:")
print(highest_score_country[['Country name', 'score']])

print("\nCountry with the lowest happiness score:")
print(lowest_score_country[['Country name', 'score']])
# Out:
# Mean Score: 5.52758041958042
# Median Score: 5.785
# Standard Deviation of Score: 1.1707165099442995
#
# Country with the highest happiness score:
# Country name    Finland
# score             7.741
# Name: 0, dtype: object
#
# Country with the lowest happiness score:
# Country name    Afghanistan
# score                 1.721
# Name: 142, dtype: object

# %%
#Missing Values:


import pandas as pd
import numpy as np

df = pd.read_csv('//content/drive/MyDrive/Coursework1/WHR-2024-5CS037.csv')

missing_values = df.isnull().sum()
print("\nMissing values per column:\n", missing_values)
# Out:
# Missing values per column:
#  Country name                    0
# score                           0
# Log GDP per capita              3
# Social support                  3
# Healthy life expectancy         3
# Freedom to make life choices    3
# Generosity                      3
# Perceptions of corruption       3
# Dystopia + residual             3
# dtype: int64

# %%
# Filtering and Sorting

filtered_df = df[df['score'] > 7.5]

sorted_df = filtered_df.sort_values(by='Log GDP per capita', ascending=False)
top_10_gdp = sorted_df.head(10)

print("\nTop 10 countries by GDP per Capita (Score > 7.5):")
top_10_gdp
# Out:
# Top 10 countries by GDP per Capita (Score > 7.5):
#   Country name  score  Log GDP per capita  Social support  \
# 1      Denmark  7.583               1.908           1.520
# 2      Iceland  7.525               1.881           1.617
# 0      Finland  7.741               1.844           1.572
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 1                    0.699                         0.823       0.204
# 2                    0.718                         0.819       0.258
# 0                    0.695                         0.859       0.142
#
#    Perceptions of corruption  Dystopia + residual
# 1                      0.548                1.881
# 2                      0.182                2.050
# 0                      0.546                2.082

# %%
# Adding New Columns
import pandas as pd
import numpy as np

df = pd.read_csv('/content/drive/MyDrive/Coursework1/WHR-2024-5CS037.csv')

def categorize_happiness(score):
    if score < 4:
        return 'Low'
    elif score <= 6:
        return 'Medium'
    else:
        return 'High'

df['Happiness Category'] = df['score'].apply(categorize_happiness)

print("\nDataFrame with Happiness Category:")
print(df.head(10))
# Out:
# DataFrame with Happiness Category:
#   Country name  score  Log GDP per capita  Social support  \
# 0      Finland  7.741               1.844           1.572
# 1      Denmark  7.583               1.908           1.520
# 2      Iceland  7.525               1.881           1.617
# 3       Sweden  7.344               1.878           1.501
# 4       Israel  7.341               1.803           1.513
# 5  Netherlands  7.319               1.901           1.462
# 6       Norway  7.302               1.952           1.517
# 7   Luxembourg  7.122               2.141           1.355
# 8  Switzerland  7.060               1.970           1.425
# 9    Australia  7.057               1.854           1.461
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.695                         0.859       0.142
# 1                    0.699                         0.823       0.204
# 2                    0.718                         0.819       0.258
# ...

# %%
# 2.Data Visualizations:

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns


# Bar Plot
top_10_happiest = df.sort_values('score', ascending=False).head(10)
plt.figure(figsize=(12, 6))
sns.barplot(x='Country name', y='score', data=top_10_happiest)
plt.xticks(rotation=45, ha='right')
plt.title('Top 10 Happiest Countries')
plt.xlabel('Country')
plt.ylabel('Happiness Score')
plt.show()

# Line Plot
top_10_unhappiest = df.sort_values('score', ascending=True).head(10)
plt.figure(figsize=(12, 6))
sns.lineplot(x='Country name', y='score', data=top_10_unhappiest, marker='o',color='red')
plt.xticks(rotation=45, ha='right')
plt.title('Top 10 Unhappiest Countries')
plt.xlabel('Country')
plt.ylabel('Happiness Score')
plt.show()

# Histogram for Score
plt.figure(figsize=(8, 6))
sns.histplot(df['score'], bins=20, kde=True) # kde=True adds a kernel density estimate
plt.title('Distribution of Happiness Scores')
plt.xlabel('Happiness Score')
plt.ylabel('Frequency')
plt.show()

# Scatter Plot
plt.figure(figsize=(8, 6))
sns.scatterplot(x='Log GDP per capita', y='score', data=df)
plt.title('Relationship between GDP per Capita and Happiness Score')
plt.xlabel('Log GDP per Capita')
plt.ylabel('Happiness Score')
plt.show()

# %%
#Task - 1:
import pandas as pd

south_asian_countries = ["Afghanistan", "Bangladesh", "Bhutan", "India",
                        "Maldives", "Nepal", "Pakistan", "Sri Lanka"]

# Load the DataFrame
df = pd.read_csv('/content/drive/MyDrive/Coursework1/WHR-2024-5CS037.csv')

# Filter the DataFrame
south_asia_df = df[df['Country name'].isin(south_asian_countries)]

# Save the filtered DataFrame to a CSV file
south_asia_df.to_csv('south_asia_happiness.csv', index=False)
print(south_asia_df)
# Out:
#     Country name  score  Log GDP per capita  Social support  \
# 92         Nepal  5.158               0.965           0.990
# 107     Pakistan  4.657               1.069           0.600
# 125        India  4.054               1.166           0.653
# 127    Sri Lanka  3.898               1.361           1.179
# 128   Bangladesh  3.886               1.122           0.249
# 142  Afghanistan  1.721               0.628           0.000
#
#      Healthy life expectancy  Freedom to make life choices  Generosity  \
# 92                     0.443                         0.653       0.209
# 107                    0.321                         0.542       0.144
# 125                    0.417                         0.767       0.174
# 127                    0.586                         0.583       0.144
# 128                    0.513                         0.775       0.140
# 142                    0.242                         0.000       0.091
#
# ...

# %%
# Task - 2
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns


# Calculate Composite Score
south_asia_df['Composite Score'] = (0.40 * south_asia_df['Log GDP per capita'] +
                                   0.30 * south_asia_df['Social support'] +
                                   0.30 * south_asia_df['Healthy life expectancy'])

# Rank countries based on Composite Score
south_asia_df = south_asia_df.sort_values(by='Composite Score', ascending=False)
south_asia_df = south_asia_df.reset_index(drop=True)  # Reset index for ranking

# Visualize top 5 countries
plt.figure(figsize=(10, 6)) # Now plt is defined and can be used
sns.barplot(x='Composite Score', y='Country name', data=south_asia_df.head(5), palette="viridis")
plt.title('Top 5 South Asian Countries by Composite Score')
plt.xlabel('Composite Score')
plt.ylabel('Country')
plt.show()


# Compare rankings with original Score
plt.figure(figsize=(10, 6))
plt.plot(south_asia_df['score'], label='Original Score')
plt.plot(south_asia_df['Composite Score'], label='Composite Score')
plt.xticks(range(len(south_asia_df)), south_asia_df['Country name'], rotation=90)

plt.title('Comparison of Original Score and Composite Score in South Asia')
plt.xlabel('Country')
plt.ylabel('Score')
plt.legend()
plt.show()
# Out:
# <ipython-input-19-386b621dbfbd>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   south_asia_df['Composite Score'] = (0.40 * south_asia_df['Log GDP per capita'] +
# <ipython-input-19-386b621dbfbd>:18: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Composite Score', y='Country name', data=south_asia_df.head(5), palette="viridis")

# %%
#Task - 3
# Calculate IQR for GDP per Capita and Score
Q1_gdp = south_asia_df['Log GDP per capita'].quantile(0.25)
Q3_gdp = south_asia_df['Log GDP per capita'].quantile(0.75)
IQR_gdp = Q3_gdp - Q1_gdp

Q1_score = south_asia_df['score'].quantile(0.25)
Q3_score = south_asia_df['score'].quantile(0.75)
IQR_score = Q3_score - Q1_score

# Define outlier boundaries
lower_bound_gdp = Q1_gdp - 1.5 * IQR_gdp
upper_bound_gdp = Q3_gdp + 1.5 * IQR_gdp

lower_bound_score = Q1_score - 1.5 * IQR_score
upper_bound_score = Q3_score + 1.5 * IQR_score

# Identify outliers
outliers = south_asia_df[
    (south_asia_df['Log GDP per capita'] < lower_bound_gdp) |
    (south_asia_df['Log GDP per capita'] > upper_bound_gdp) |
    (south_asia_df['score'] < lower_bound_score) |
    (south_asia_df['score'] > upper_bound_score)
]

# Create the scatter plot
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Log GDP per capita', y='score', data=south_asia_df, hue=south_asia_df.index.isin(outliers.index), palette={True: 'red', False: 'blue'}) #Highlight outliers
plt.title('Outlier Detection in South Asian Countries')
plt.xlabel('Log GDP per Capita')
plt.ylabel('Happiness Score')
plt.show()

# Discuss the characteristics of outliers and their potential impact (add your analysis here)
print("Outlier Countries:")
print(outliers[['Country name', 'Log GDP per capita', 'score']])
# Out:
# Outlier Countries:
#   Country name  Log GDP per capita  score
# 5  Afghanistan               0.628  1.721

# %%
# Task - 4

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the South Asian countries data
south_asia_df = pd.read_csv('south_asia_happiness.csv')

# Calculate Pearson correlation
metrics = ['Freedom to make life choices', 'Generosity']
for metric in metrics:
    correlation = south_asia_df['score'].corr(south_asia_df[metric], method='pearson')
    print(f"Pearson correlation between Score and {metric}: {correlation}")

# Create scatter plots with trendlines
for metric in metrics:
    plt.figure(figsize=(8, 6))
    sns.regplot(x=metric, y='score', data=south_asia_df)
    plt.title(f'Scatter Plot of Score vs. {metric} in South Asian Countries')
    plt.xlabel(metric)
    plt.ylabel('Score')
    plt.show()
# Out:
# Pearson correlation between Score and Freedom to make life choices: 0.8005185224163315
# Pearson correlation between Score and Generosity: 0.874512371253192

# %%
# Task - 5:

# Add GDP-Score Gap column
south_asia_df['GDP-Score Gap'] = south_asia_df['Log GDP per capita'] - south_asia_df['score']

# Rank by GDP-Score Gap
south_asia_df_ascending = south_asia_df.sort_values(by='GDP-Score Gap')
south_asia_df_descending = south_asia_df.sort_values(by='GDP-Score Gap', ascending=False)

# Highlight top 3 countries with largest positive and negative gaps
plt.figure(figsize=(12, 6))

# Top 3 positive gaps
plt.subplot(1, 2, 1)
sns.barplot(x='Country name', y='GDP-Score Gap', data=south_asia_df_descending.head(3), palette="viridis")
plt.xticks(rotation=45, ha='right')
plt.title('Top 3 Countries: Largest Positive GDP-Score Gap')

# Top 3 negative gaps
plt.subplot(1, 2, 2)
sns.barplot(x='Country name', y='GDP-Score Gap', data=south_asia_df_ascending.head(3), palette="viridis")
plt.xticks(rotation=45, ha='right')
plt.title('Top 3 Countries: Largest Negative GDP-Score Gap')

plt.tight_layout()
plt.show()

#  Analyze reasons behind the gaps (add your analysis here)
print("\nAnalysis of GDP-Score Gaps:")
print("Countries with large positive gaps might have high GDP but lower social support, health, or freedom.")
print("Countries with large negative gaps might have lower GDP but higher social support, health or freedom, which could improve happiness score.")
# Out:
# <ipython-input-23-21ce36ce9831>:15: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Country name', y='GDP-Score Gap', data=south_asia_df_descending.head(3), palette="viridis")
# <ipython-input-23-21ce36ce9831>:21: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Country name', y='GDP-Score Gap', data=south_asia_df_ascending.head(3), palette="viridis")
# Analysis of GDP-Score Gaps:
# Countries with large positive gaps might have high GDP but lower social support, health, or freedom.
# Countries with large negative gaps might have lower GDP but higher social support, health or freedom, which could improve happiness score.

# %%
# Task - 5:

# Add GDP-Score Gap column
south_asia_df['GDP-Score Gap'] = south_asia_df['Log GDP per capita'] - south_asia_df['score']

# Rank by GDP-Score Gap
south_asia_df_ascending = south_asia_df.sort_values(by='GDP-Score Gap')
south_asia_df_descending = south_asia_df.sort_values(by='GDP-Score Gap', ascending=False)

# Highlight top 3 countries with largest positive and negative gaps
plt.figure(figsize=(12, 6))

# Top 3 positive gaps
plt.subplot(1, 2, 1)
sns.barplot(x='Country name', y='GDP-Score Gap', data=south_asia_df_descending.head(3), palette="viridis")
plt.xticks(rotation=45, ha='right')
plt.title('Top 3 Countries: Largest Positive GDP-Score Gap')

# Top 3 negative gaps
plt.subplot(1, 2, 2)
sns.barplot(x='Country name', y='GDP-Score Gap', data=south_asia_df_ascending.head(3), palette="viridis")
plt.xticks(rotation=45, ha='right')
plt.title('Top 3 Countries: Largest Negative GDP-Score Gap')

plt.tight_layout()
plt.show()

#  Analyze reasons behind the gaps (add your analysis here)
print("\nAnalysis of GDP-Score Gaps:")
print("Countries with large positive gaps might have high GDP but lower social support, health, or freedom.")
print("Countries with large negative gaps might have lower GDP but higher social support, health or freedom, which could improve happiness score.")
# Out:
# <ipython-input-25-21ce36ce9831>:15: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Country name', y='GDP-Score Gap', data=south_asia_df_descending.head(3), palette="viridis")
# <ipython-input-25-21ce36ce9831>:21: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Country name', y='GDP-Score Gap', data=south_asia_df_ascending.head(3), palette="viridis")
# Analysis of GDP-Score Gaps:
# Countries with large positive gaps might have high GDP but lower social support, health, or freedom.
# Countries with large negative gaps might have lower GDP but higher social support, health or freedom, which could improve happiness score.

# %%
# Task - 1

# Create a list of Middle Eastern countries
middle_east_countries = ["Bahrain", "Iran", "Iraq", "Israel", "Jordan", "Kuwait", "Lebanon", "Oman", "Palestine", "Qatar", "Saudi Arabia", "Syria", "United Arab Emirates", "Yemen"]

# Filter the DataFrame to include only Middle Eastern countries
middle_east_df = df[df['Country name'].isin(middle_east_countries)]

# Calculate the mean and standard deviation of the score for the Middle East
mean_score_middle_east = middle_east_df['score'].mean()
std_dev_score_middle_east = middle_east_df['score'].std()

# Assuming you have already calculated the mean and standard deviation for South Asia (from the previous task)
# Replace these with your actual values
mean_score_south_asia = south_asia_df['score'].mean()  # Assuming south_asia_df is from previous task
std_dev_score_south_asia = south_asia_df['score'].std() # Assuming south_asia_df is from previous task


print(f"Mean Happiness Score (Middle East): {mean_score_middle_east}")
print(f"Standard Deviation of Happiness Score (Middle East): {std_dev_score_middle_east}")
print(f"Mean Happiness Score (South Asia): {mean_score_south_asia}")
print(f"Standard Deviation of Happiness Score (South Asia): {std_dev_score_south_asia}")

# Compare the average happiness scores
if mean_score_middle_east > mean_score_south_asia:
    print("The Middle East has higher average happiness scores.")
elif mean_score_middle_east < mean_score_south_asia:
    print("South Asia has higher average happiness scores.")
else:
    print("Both regions have the same average happiness score.")
# Out:
# Mean Happiness Score (Middle East): 5.412100000000001
# Standard Deviation of Happiness Score (Middle East): 1.5662011684327144
# Mean Happiness Score (South Asia): 3.895666666666667
# Standard Deviation of Happiness Score (South Asia): 1.1770690152521504
# The Middle East has higher average happiness scores.

# %%
# Task 2: Top and Bottom Performers

def plot_top_bottom(df, region_name):
    """Identifies and plots top/bottom performers for a region."""

    # Sort by score within the region
    region_df_sorted = df.sort_values(by='score', ascending=False)

    # Get top and bottom 3 countries
    top3 = region_df_sorted.head(3)
    bottom3 = region_df_sorted.tail(3)

    # Plotting
    plt.figure(figsize=(12, 6))

    plt.subplot(1, 2, 1)
    sns.barplot(x='Country name', y='score', data=top3, palette="viridis")
    plt.xticks(rotation=45, ha='right')
    plt.title(f'Top 3 Happiest Countries in {region_name}')

    plt.subplot(1, 2, 2)
    sns.barplot(x='Country name', y='score', data=bottom3, palette="viridis")
    plt.xticks(rotation=45, ha='right')
    plt.title(f'Bottom 3 Happiest Countries in {region_name}')

    plt.tight_layout()
    plt.show()

# Example usage (assuming you have 'middle_east_df' and 'south_asia_df' from previous tasks):
plot_top_bottom(middle_east_df, "Middle East")
plot_top_bottom(south_asia_df, "South Asia")
# Out:
# <ipython-input-27-a174a3373218>:17: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Country name', y='score', data=top3, palette="viridis")
# <ipython-input-27-a174a3373218>:22: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Country name', y='score', data=bottom3, palette="viridis")
# <ipython-input-27-a174a3373218>:17: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Country name', y='score', data=top3, palette="viridis")
# <ipython-input-27-a174a3373218>:22: FutureWarning:
#
# ...

# %%
# Task 3: Metric Comparisons

# Define the metrics for comparison
metrics = ['Log GDP per capita', 'Social support', 'Healthy life expectancy']

# Create grouped bar charts for each metric
for metric in metrics:
    plt.figure(figsize=(10, 6))

    # Create the grouped barplot
    sns.barplot(x='Country name', y=metric, data=middle_east_df, color='brown', label='Middle East')
    sns.barplot(x='Country name', y=metric, data=south_asia_df, color='orange', label='South Asia')

    plt.xticks(rotation=45, ha='right')
    plt.title(f'Comparison of {metric} between Middle East and South Asia')
    plt.xlabel('Country')
    plt.ylabel(metric)
    plt.legend()
    plt.tight_layout()
    plt.show()



for metric in metrics:
    diff_mean = abs(middle_east_df[metric].mean() - south_asia_df[metric].mean())
    print(f'Mean difference in {metric}: {diff_mean}')
# Out:
# Mean difference in Log GDP per capita: 0.4444999999999999
# Mean difference in Social support: 0.5409444444444443
# Mean difference in Healthy life expectancy: 0.13377777777777783

# %%
# Create a list of Middle Eastern countries
middle_east_countries = ["Bahrain", "Iran", "Iraq", "Israel", "Jordan", "Kuwait", "Lebanon", "Oman", "Palestine", "Qatar", "Saudi Arabia", "Syria", "United Arab Emirates", "Yemen"]

# Filter the DataFrame to include only Middle Eastern countries
middle_east_df = df[df['Country name'].isin(middle_east_countries)]

# Now you have the middle_east_df DataFrame containing data for Middle Eastern countries
middle_east_df
# Out:
#              Country name  score  Log GDP per capita  Social support  \
# 4                  Israel  7.341               1.803           1.513
# 12                 Kuwait  6.951               1.845           1.364
# 21   United Arab Emirates  6.733               1.983           1.164
# 27           Saudi Arabia  6.594               1.842           1.361
# 61                Bahrain  5.959                 NaN             NaN
# 91                   Iraq  5.166               1.249           0.996
# 99                   Iran  4.923               1.435           1.136
# 124                Jordan  4.186               1.262           0.983
# 132                 Yemen  3.561               0.671           1.281
# 141               Lebanon  2.707               1.377           0.577
#
#      Healthy life expectancy  Freedom to make life choices  Generosity  \
# 4                      0.740                         0.641       0.153
# ...

# %% [markdown]
# **Which region has greater variability in happiness?**
#
# To find out which region has more variability in happiness, you would compare the Coefficient of Variation (CV) for both regions. The region with the higher CV indicates greater variability in happiness scores.
#
# A higher CV means more variability in happiness.
# By calculating the CV for each region, you’ll be able to determine which region has the most variability in its happiness scores.

# %%
# • Create scatter plots to visualize and interpret the relationships.

# Create a list of Middle Eastern countries
middle_east_countries = ["Bahrain", "Iran", "Iraq", "Israel", "Jordan", "Kuwait", "Lebanon", "Oman", "Palestine", "Qatar", "Saudi Arabia", "Syria", "United Arab Emirates", "Yemen"]

# Filter the DataFrame to include only Middle Eastern countries
middle_east_df = df[df['Country name'].isin(middle_east_countries)]

# Display the DataFrame
middle_east_df
# Out:
#              Country name  score  Log GDP per capita  Social support  \
# 4                  Israel  7.341               1.803           1.513
# 12                 Kuwait  6.951               1.845           1.364
# 21   United Arab Emirates  6.733               1.983           1.164
# 27           Saudi Arabia  6.594               1.842           1.361
# 61                Bahrain  5.959                 NaN             NaN
# 91                   Iraq  5.166               1.249           0.996
# 99                   Iran  4.923               1.435           1.136
# 124                Jordan  4.186               1.262           0.983
# 132                 Yemen  3.561               0.671           1.281
# 141               Lebanon  2.707               1.377           0.577
#
#      Healthy life expectancy  Freedom to make life choices  Generosity  \
# 4                      0.740                         0.641       0.153
# ...

# %%
# • Plot these outliers and discuss their implications.

# Create a list of Middle Eastern countries
middle_east_countries = ["Bahrain", "Iran", "Iraq", "Israel", "Jordan", "Kuwait", "Lebanon", "Oman", "Palestine", "Qatar", "Saudi Arabia", "Syria", "United Arab Emirates", "Yemen"]

# Filter the DataFrame to include only Middle Eastern countries
middle_east_df = df[df['Country name'].isin(middle_east_countries)]

# Display the DataFrame
middle_east_df
# Out:
#              Country name  score  Log GDP per capita  Social support  \
# 4                  Israel  7.341               1.803           1.513
# 12                 Kuwait  6.951               1.845           1.364
# 21   United Arab Emirates  6.733               1.983           1.164
# 27           Saudi Arabia  6.594               1.842           1.361
# 61                Bahrain  5.959                 NaN             NaN
# 91                   Iraq  5.166               1.249           0.996
# 99                   Iran  4.923               1.435           1.136
# 124                Jordan  4.186               1.262           0.983
# 132                 Yemen  3.561               0.671           1.281
# 141               Lebanon  2.707               1.377           0.577
#
#      Healthy life expectancy  Freedom to make life choices  Generosity  \
# 4                      0.740                         0.641       0.153
# ...

# %%
# • Interpret the key differences in distribution shapes, medians, and outliers.


# Create a list of Middle Eastern countries
middle_east_countries = ["Bahrain", "Iran", "Iraq", "Israel", "Jordan", "Kuwait", "Lebanon", "Oman", "Palestine", "Qatar", "Saudi Arabia", "Syria", "United Arab Emirates", "Yemen"]

# Filter the DataFrame to include only Middle Eastern countries
middle_east_df = df[df['Country name'].isin(middle_east_countries)]


# Visualization: Boxplots comparing South Asia and the Middle East
plt.figure(figsize=(10, 6))
sns.boxplot(x='Region', y='score', data=pd.concat([south_asia_df.assign(Region='South Asia'),
                                                  middle_east_df.assign(Region='Middle East')]))
plt.title('Distribution of Happiness Scores: South Asia vs. Middle East')
plt.show()

# %% [markdown]
# **Interpretation of Boxplots for Happiness Scores in South Asia vs. the Middle East:**
#
# Distribution Shapes:
# •	South Asia: The boxplot for South Asia likely shows a right-skewed distribution, meaning that most countries have lower happiness scores, but there are a few outliers with higher scores. This suggests that while the majority of South Asian countries have relatively low happiness levels, there are a few exceptions where the scores are higher.
#
# •	Middle East: The boxplot for the Middle East may appear more symmetrical or slightly skewed to the right, but it could have a wider spread compared to South Asia. This indicates that the happiness scores in the Middle East are more evenly distributed, with more variability across countries.
# Medians:
#
# •	South Asia: The median happiness score in South Asia is likely lower, reflecting the generally lower happiness levels across this region.
# •	Middle East: The median for the Middle East is expected to be higher than South Asia’s, suggesting that, on average, people in the Middle East are happier.
#
# Outliers:
# •	South Asia: South Asia might have a few countries that are outliers—those with extremely high or low happiness scores. These countries could stand out due to unique socio-political factors or varying levels of well-being or dissatisfaction.
#
# •	Middle East: The Middle East may also have outliers, but they could be fewer in number. When they do appear, they may represent exceptional cases such as high-income countries or those facing specific challenges like political instability that could skew the happiness scores.
#
# Conclusion:
# •	The Middle East generally has a higher median happiness score and its happiness scores are more spread out compared to South Asia, where most countries cluster towards the lower end of the happiness spectrum. Both regions show outliers, indicating that there are some countries that significantly deviate from the norm within each region.
